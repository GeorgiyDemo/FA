# %% [markdown]
# ## Вычисления для домашней работы по Финансовой математике

# %% [markdown]
# #### ПИ19-3 Деменчук Георгий

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime

# %%
custom_date_parser = lambda x: datetime.datetime.strptime(x, "%d-%m-%Y")
data = pd.read_csv("./data.csv", delimiter=";",parse_dates=["DATE"],date_parser=custom_date_parser)
data
# Out:
#          DATE  Aligent  Centene  DEXcom  Carmax   Amazon  Voniter  Equinix  \
# 0  2021-09-24  172.390    62.82  561.17  144.45  3426.98   34.890   834.62
# 1  2021-09-27  166.530    63.82  548.54  145.24  3406.22   34.860   807.66
# 2  2021-09-28  159.820    63.54  536.92  143.01  3317.28   34.450   799.48
# 3  2021-09-29  160.090    63.26  544.83  146.50  3301.40   34.420   801.38
# 4  2021-09-30  157.470    62.30  546.94  127.96  3285.40   33.620   790.12
# 5  2021-10-01  155.940    63.05  549.61  127.17  3282.15   34.040   789.18
# 6  2021-10-04  152.360    62.53  526.29  122.50  3191.12   33.720   785.00
# 7  2021-10-05  152.995    62.72  540.49  126.26  3219.03   33.820   760.73
# 8  2021-10-06  153.670    63.04  541.81  129.31  3263.74   33.250   761.86
# 9  2021-10-07  155.250    63.98  539.05  131.33  3300.49   33.675   766.16
# 10 2021-10-08  152.470    64.33  529.61  130.53  3288.83   33.780   750.51
# ...

# %%
data.dtypes
# Out:
# DATE                                          datetime64[ns]
# Aligent                                              float64
# Centene                                              float64
# DEXcom                                               float64
# Carmax                                               float64
# Amazon                                               float64
# Voniter                                              float64
# Equinix                                              float64
# Laboratory corporation of american holding           float64
# Baxter Internatinal                                  float64
# Lowe's companies                                     float64
# S&P                                                  float64
# dtype: object

# %%
all_items_list = ("Aligent", "Centene", "DEXcom", "Carmax", "Amazon", "Voniter", "Equinix", "Laboratory corporation of american holding", "Baxter Internatinal", "Lowe's companies", "S&P")

# %%
def show_plot(df, plot_name):
    
    plt.figure(figsize=(15,15))
    dates = df["DATE"]
    for item in all_items_list:
        plt.plot(dates, df[item], label=item)

    plt.legend()
    plt.savefig(f'./img/{plot_name}.png')
    plt.show()

# %% [markdown]
# ### График по-умолчанию

# %%
show_plot(data, "result_standard")

# %% [markdown]
# ### График с min-max нормализацией

# %%
normalized_df=(data-data.min())/(data.max()-data.min())

# %%
normalized_df["DATE"] = data["DATE"]
normalized_df
# Out:
#          DATE   Aligent   Centene    DEXcom    Carmax    Amazon   Voniter  \
# 0  2021-09-24       1.0  0.122253  0.830081  0.914583  0.922842       1.0
# 1  2021-09-27  0.760327  0.259615   0.52951    0.9475  0.841615  0.987179
# 2  2021-09-28   0.48589  0.221154  0.252975  0.854583  0.493622  0.811966
# 3  2021-09-29  0.496933  0.182692  0.441218       1.0  0.431489  0.799145
# 4  2021-09-30  0.389775  0.050824  0.491433    0.2275  0.368886  0.457265
# 5  2021-10-01  0.327198  0.153846  0.554974  0.194583   0.35617  0.636752
# 6  2021-10-04  0.180777  0.082418       0.0       0.0       0.0       0.5
# 7  2021-10-05  0.206748  0.108516  0.337934  0.156667  0.109203  0.542735
# 8  2021-10-06  0.234356  0.152473  0.369348   0.28375  0.284138  0.299145
# 9  2021-10-07  0.298978  0.281593  0.303665  0.367917  0.427929  0.480769
# 10 2021-10-08  0.185276   0.32967   0.07901  0.334583  0.382307  0.525641
# 11 2021-10-11  0.084663  0.159341  0.046882  0.282917  0.214297       0.0
# ...

# %%
show_plot(normalized_df, "normalized_df")

# %% [markdown]
# ### График log

# %%
log_df = data.copy(deep=False)

# %%
for item in all_items_list:
    log_df[item] = np.log(log_df[item])
log_df
# Out:
#          DATE   Aligent   Centene    DEXcom    Carmax    Amazon   Voniter  \
# 0  2021-09-24  5.149759  4.140273  6.330024  4.972933  8.139435  3.552200
# 1  2021-09-27  5.115175  4.156067  6.307260  4.978388  8.133358  3.551340
# 2  2021-09-28  5.074048  4.151670  6.285849  4.962915  8.106900  3.539509
# 3  2021-09-29  5.075736  4.147253  6.300474  4.987025  8.102102  3.538638
# 4  2021-09-30  5.059235  4.131961  6.304339  4.851718  8.097244  3.515121
# 5  2021-10-01  5.049471  4.143928  6.309209  4.845525  8.096254  3.527536
# 6  2021-10-04  5.026246  4.135646  6.265852  4.808111  8.068127  3.518091
# 7  2021-10-05  5.030405  4.138680  6.292476  4.838343  8.076835  3.521052
# 8  2021-10-06  5.034807  4.143769  6.294915  4.862213  8.090629  3.504055
# 9  2021-10-07  5.045037  4.158571  6.289808  4.877713  8.101826  3.516756
# 10 2021-10-08  5.026968  4.164026  6.272141  4.871603  8.098287  3.519869
# 11 2021-10-11  5.010702  4.144562  6.269589  4.862058  8.085145  3.482777
# ...

# %%
show_plot(log_df, "result_log")

# %% [markdown]
# ### Корреляции

# %%
# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(data.corr(), xticklabels=data.corr().columns, yticklabels=data.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Коррелограмма акций', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('./img/correl_all.png')
plt.show()

# %%
plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(data, kind="reg")
plt.savefig('./img/correl_all_plts.png')
plt.show()
