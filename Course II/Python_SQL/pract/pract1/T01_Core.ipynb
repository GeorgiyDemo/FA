# %% [markdown]
# <PRE>
# Федеральное государственное образовательное бюджетное учреждение высшего образования
#            Финансовый университет при Правительстве Российской Федерации
#                               (Финансовый университет)
#
#                  Дисциплина «Программирование на языках Python и SQL»
# </Pre>

# %% [markdown]
# 5 февраля 2021 года <br>
# Семинар <br>
# ПИ19-3, ПИ19-4 - 3 подгруппа

# %% [markdown]
# # Тема 1. SQLAlchemy и язык выражений SQL
# SQL Expression Language

# %% [markdown]
# # Введение

# %% [markdown]
# ## SQLAlchemy и язык выражений SQL
#
# SQLAlchemy - библиотека Пайтон, которая устраняет разрыв между реляционными базами данных и традиционным программированием. Хотя SQLAlchemy позволяет «опуститься» до необработанного SQL для выполнения запросов, она поощряет мышление более высокого уровня за счет более «питонического» и дружественного подхода к запросам и обновлению базы данных. SQLAlchemy используется для взаимодействия с широким спектром баз данных. Она позволяет создавать модели данных и запросы в манере, напоминающей обычные классы и операторы Python.
#
# Язык выражений SQL (SQL Expression Language), называемый также Кор (Core, ядро) - это инструмент SQLAlchemy для представления общих операторов и выражений SQL в стиде Пайтон. Он ориентирован на фактическую схему базы данных и стандартизирован таким образом, что обеспечивает единообразный язык для большого числа серверных баз данных.
#
# SQLAlchemy Core имеет представление, ориентированное на схему, таблицы, ключи и индексы, как и традиционный SQL. SQLAlchemy Core эффективен в отчетах, анализе и других применениях, где полезно иметь возможность жестко контролировать запрос или работать с немоделированными данными. Надежный пул соединений с базой данных и оптимизация набора результатов идеально подходят для работы с большими объемами данных.

# %% [markdown]
# ## Кодирование
#
# Работать с SQLAlchemy удобно в интерактивной среде "чтение-оценка-вывод" (REPL), в такой, как интерактивный ноутбук ipython http://ipython.org/
#
# Установка Юпитер Ноутбук
# https://jupyter.readthedocs.io/en/latest/install/notebook-classic.html
#
# Для освоения и работы с ноутбуком iPython, рекомендуется пакет программ Анаконда (Anaconda).
#
# https://www.anaconda.com/products/individual
#
# Анаконда содержит Пайтон, Юпитер ноутбук и другие часто используемые приложения для научных вычислений и обработки данных.
#
# Порядок установки и запуска интерктивной среды Юпитер ноутбук
#
# 1. Загрузить Анаконда
# 2. Установить Анаконда
# 3. Запустить Юпитер ноутбук. Для этого использовать команду меню, либо консольную команду
#
#     => jupyter notebook

# %% [markdown]
# ## Установка SQLAlchemy

# %%
! pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.9/site-packages (1.3.23)

# %% [markdown]
# ## Установка драйверов баз данных
#
# По умолчанию SQLAlchemy поддерживает SQLite3 без дополнительных драйверов. Для подключения к другим базам данных необходимы дополнительные драйвера баз данных.
#
# - PostgreSQL. Установка драйвера Psycopg2: http://initd.org/psycopg/
# - MySQL (требуется версия MySQL  4.1  и выше)
# - Другие
#
# SQLAlchemy также можно использовать вместе с Drizzle, Firebird, Oracle, Syb-ase и Microsoft SQL Server. Сообщество также предоставило внешние диалекты для многих других баз данных, таких как IBM DB2, Informix, Amazon Redshift, EXASolution, SAP SQL Anywhere, Monet и многих других. Создание диалектов поддерживается SQLAlchemy.

# %%
# PostgreSQL
! pip install psycopg2

# MySQL
! pip  install  pymysql
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.8.6.tar.gz (383 kB)
#      |████████████████████████████████| 383 kB 2.4 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_e398d4ad9efb466e906d075e1e2b9786/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_e398d4ad9efb466e906d075e1e2b9786/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-ie7bazu6
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_e398d4ad9efb466e906d075e1e2b9786/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-ie7bazu6/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-ie7bazu6/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-ie7bazu6/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-ie7bazu6/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-ie7bazu6/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/fd/ae/98cb7a0cbb1d748ee547b058b14604bd0e9bf285a8e0cc5d148f8a8a952e/psycopg2-2.8.6.tar.gz#sha256=fb23f6c71107c37fd667cb4ea363ddeb936b348bbd6449278eb92c189699f543 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.5.tar.gz (380 kB)
#      |████████████████████████████████| 380 kB 7.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_b82e7cdca1264a1885830e7b13e4b8ef/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_b82e7cdca1264a1885830e7b13e4b8ef/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-syybh3ly
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_b82e7cdca1264a1885830e7b13e4b8ef/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-syybh3ly/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-syybh3ly/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-syybh3ly/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-syybh3ly/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-syybh3ly/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a8/8f/1c5690eebf148d1d1554fc00ccf9101e134636553dbb75bdfef4f85d7647/psycopg2-2.8.5.tar.gz#sha256=f7d46240f7a1ae1dd95aab38bd74f7428d46531f69219954266d669da60c0818 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.4.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 7.9 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_0e83a512740043c79c1a03cd8e526c55/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_0e83a512740043c79c1a03cd8e526c55/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-bcs0z_v7
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_0e83a512740043c79c1a03cd8e526c55/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-bcs0z_v7/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-bcs0z_v7/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-bcs0z_v7/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-bcs0z_v7/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-bcs0z_v7/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/84/d7/6a93c99b5ba4d4d22daa3928b983cec66df4536ca50b22ce5dcac65e4e71/psycopg2-2.8.4.tar.gz#sha256=f898e5cc0a662a9e12bde6f931263a1bbd350cfb18e1d5336a12927851825bb6 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.3.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 3.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_e8c97d6e08aa4c6b8e2df01e2a96a1de/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_e8c97d6e08aa4c6b8e2df01e2a96a1de/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-e4o9w9bf
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_e8c97d6e08aa4c6b8e2df01e2a96a1de/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-e4o9w9bf/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-e4o9w9bf/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-e4o9w9bf/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-e4o9w9bf/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-e4o9w9bf/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/1c/6997288da181277a0c29bc39a5f9143ff20b8c99f2a7d059cfb55163e165/psycopg2-2.8.3.tar.gz#sha256=897a6e838319b4bf648a574afb6cabcb17d0488f8c7195100d48d872419f4457 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.2.tar.gz (368 kB)
#      |████████████████████████████████| 368 kB 7.7 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_3f0164b62e8f466e8354ad41e1910844/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_3f0164b62e8f466e8354ad41e1910844/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-08f1gkq3
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_3f0164b62e8f466e8354ad41e1910844/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-08f1gkq3/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-08f1gkq3/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-08f1gkq3/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-08f1gkq3/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-08f1gkq3/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/23/7e/93c325482c328619870b6cd09370f6dbe1148283daca65115cd63642e60f/psycopg2-2.8.2.tar.gz#sha256=5cacf21b6f813c239f100ef78a4132056f93a5940219ec25d2ef833cbeb05588 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.1.tar.gz (367 kB)
#      |████████████████████████████████| 367 kB 4.3 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_3e533b3a8d3e45af872e694add5f8802/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_3e533b3a8d3e45af872e694add5f8802/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-dfr783a0
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_3e533b3a8d3e45af872e694add5f8802/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-dfr783a0/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-dfr783a0/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-dfr783a0/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-dfr783a0/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-dfr783a0/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/52/be/f898e712f5f08131d651a62754fca82a1deb42e4e9889ad01932f770a2be/psycopg2-2.8.1.tar.gz#sha256=b4a475ce87eabc0607e068a3c704d0aa0820237ed78d493b8e2d880eb73cd7fe (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.tar.gz (367 kB)
#      |████████████████████████████████| 367 kB 7.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_1f14d19a02b944eda73aa28927652f73/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_1f14d19a02b944eda73aa28927652f73/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-h_k1o0p1
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_1f14d19a02b944eda73aa28927652f73/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-h_k1o0p1/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-h_k1o0p1/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-h_k1o0p1/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-h_k1o0p1/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-h_k1o0p1/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c7/ca/75236b17f1b951950ffc55d657c5aa408d3d0327a1b6c4c0f7cb16ef7e7b/psycopg2-2.8.tar.gz#sha256=49c5838d90e83217909db3789d30a105385b5e696ec5168cda645546c542f35a (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.7.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 1.7 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_865e452812ff4fefa28973f94c6b54d5/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_865e452812ff4fefa28973f94c6b54d5/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-s8og9me1
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_865e452812ff4fefa28973f94c6b54d5/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-s8og9me1/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-s8og9me1/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-s8og9me1/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-s8og9me1/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-s8og9me1/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/63/54/c039eb0f46f9a9406b59a638415c2012ad7be9b4b97bfddb1f48c280df3a/psycopg2-2.7.7.tar.gz#sha256=f4526d078aedd5187d0508aa5f9a01eae6a48a470ed678406da94b4cd6524b7e (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.6.1.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 2.0 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_88e3e12264d540239e06d5d3e31467d7/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_88e3e12264d540239e06d5d3e31467d7/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-85lrh3er
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_88e3e12264d540239e06d5d3e31467d7/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-85lrh3er/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-85lrh3er/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-85lrh3er/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-85lrh3er/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-85lrh3er/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c0/07/93573b97ed61b6fb907c8439bf58f09957564cf7c39612cef36c547e68c6/psycopg2-2.7.6.1.tar.gz#sha256=27959abe64ca1fc6d8cd11a71a1f421d8287831a3262bd4cacd43bbf43cc3c82 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.6.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 7.0 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_92c17cbd3dbd4814a6fb1769954b82e8/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_92c17cbd3dbd4814a6fb1769954b82e8/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-kzs7f03d
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_92c17cbd3dbd4814a6fb1769954b82e8/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-kzs7f03d/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-kzs7f03d/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-kzs7f03d/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-kzs7f03d/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-kzs7f03d/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/94/09/2f1fae36d83e2315b90ee91738d01baf8af8c945726bf4b4708fcec3256d/psycopg2-2.7.6.tar.gz#sha256=4a658550b0bcb259e97f77f2dc93ed6b108fe2eda963a9e6fc8b48040d542ec2 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.5.tar.gz (426 kB)
#      |████████████████████████████████| 426 kB 8.7 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_8c48bdb8f8684a728c5c72da82db3a25/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_8c48bdb8f8684a728c5c72da82db3a25/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-_mu2t8vr
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_8c48bdb8f8684a728c5c72da82db3a25/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-_mu2t8vr/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-_mu2t8vr/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-_mu2t8vr/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-_mu2t8vr/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-_mu2t8vr/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b2/c1/7bf6c464e903ffc4f3f5907c389e5a4199666bf57f6cd6bf46c17912a1f9/psycopg2-2.7.5.tar.gz#sha256=eccf962d41ca46e6326b97c8fe0a6687b58dfc1a5f6540ed071ff1474cea749e (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.4.tar.gz (425 kB)
#      |████████████████████████████████| 425 kB 7.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6fc17569454e4eb2903e0135aaceb288/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6fc17569454e4eb2903e0135aaceb288/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-83i4pzt_
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6fc17569454e4eb2903e0135aaceb288/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-83i4pzt_/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-83i4pzt_/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-83i4pzt_/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-83i4pzt_/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-83i4pzt_/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/74/83/51580322ed0e82cba7ad8e0af590b8fb2cf11bd5aaa1ed872661bd36f462/psycopg2-2.7.4.tar.gz#sha256=8bf51191d60f6987482ef0cfe8511bbf4877a5aa7f313d7b488b53189cf26209 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.3.2.tar.gz (425 kB)
#      |████████████████████████████████| 425 kB 4.8 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6532c11ab28b47058ec0242eed4ad4e2/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6532c11ab28b47058ec0242eed4ad4e2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-zjl1ptrx
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6532c11ab28b47058ec0242eed4ad4e2/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-zjl1ptrx/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-zjl1ptrx/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-zjl1ptrx/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-zjl1ptrx/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-zjl1ptrx/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/dd/47/000b405d73ca22980684fd7bd3318690cc03cfa3b2ae1c5b7fff8050b28a/psycopg2-2.7.3.2.tar.gz#sha256=5c3213be557d0468f9df8fe2487eaf2990d9799202c5ff5cb8d394d09fad9b2a (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.3.1.tar.gz (425 kB)
#      |████████████████████████████████| 425 kB 7.4 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c42daf0853004c4a880a37d5178b19bc/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c42daf0853004c4a880a37d5178b19bc/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-o8jg49e_
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c42daf0853004c4a880a37d5178b19bc/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-o8jg49e_/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-o8jg49e_/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-o8jg49e_/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-o8jg49e_/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-o8jg49e_/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6b/fb/15c687eda2f925f0ff59373063fdb408471b4284714a7761daaa65c01f15/psycopg2-2.7.3.1.tar.gz#sha256=9b7b16e26448b43cf167f785d8b5345007731ebf153a510e12dae826800caa65 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.3.tar.gz (425 kB)
#      |████████████████████████████████| 425 kB 2.3 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_bce6ae7e16144ec09091cf0b5b84b6c3/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_bce6ae7e16144ec09091cf0b5b84b6c3/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-1eofnkr4
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_bce6ae7e16144ec09091cf0b5b84b6c3/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-1eofnkr4/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-1eofnkr4/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-1eofnkr4/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-1eofnkr4/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-1eofnkr4/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/98/99/33ca02c4bc3ed1bd9ceab5614bda2e6d1d31e61ec58345b9feece238c38a/psycopg2-2.7.3.tar.gz#sha256=c9bd49848556d04093909faec017c3675efabf78c2b7f383bf7c43ba18324ac8 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.2.tar.gz (424 kB)
#      |████████████████████████████████| 424 kB 4.0 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c813bd78ce1b4a48bd28217c96bcef6c/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c813bd78ce1b4a48bd28217c96bcef6c/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-g4820ys5
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c813bd78ce1b4a48bd28217c96bcef6c/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-g4820ys5/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-g4820ys5/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-g4820ys5/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-g4820ys5/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-g4820ys5/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/d0/66/61c1b34ea8da8f95d99676e6803ccad83abef3ac90df145b45033696f3d2/psycopg2-2.7.2.tar.gz#sha256=3767f40bb35713ccc75dbcff80bf228a75e080d6b98c78afd5fb9aa84682a9f4 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.1.tar.gz (421 kB)
#      |████████████████████████████████| 421 kB 3.8 MB/s eta 0:00:01     |██████████████                  | 184 kB 3.8 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c3fead46dc8545ada25642708a07d79b/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c3fead46dc8545ada25642708a07d79b/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-xqjjp6my
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_c3fead46dc8545ada25642708a07d79b/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-xqjjp6my/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-xqjjp6my/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-xqjjp6my/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-xqjjp6my/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-xqjjp6my/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f8/e9/5793369ce8a41bf5467623ded8d59a434dfef9c136351aca4e70c2657ba0/psycopg2-2.7.1.tar.gz#sha256=86c9355f5374b008c8479bc00023b295c07d508f7c3b91dbd2e74f8925b1d9c6 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.tar.gz (421 kB)
#      |███████████████████████████████▉| 419 kB 3.7 MB/s eta 0:00:01     |████████████████████████████████| 421 kB 3.7 MB/s
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_d1922eebec504c7f9eb1653e3fef577b/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_d1922eebec504c7f9eb1653e3fef577b/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-tyvdqq0m
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_d1922eebec504c7f9eb1653e3fef577b/
#     Complete output (14 lines):
#     running egg_info
#     creating /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-tyvdqq0m/psycopg2.egg-info
#     writing /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-tyvdqq0m/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-tyvdqq0m/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-tyvdqq0m/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-tyvdqq0m/psycopg2.egg-info/SOURCES.txt'
#     Error: pg_config executable not found.
#
#     Please add the directory containing pg_config to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/62/ca/0a479c9664526e86c2913a7ad593586eeb86b428b7e629e7c7b6b69e3cb7/psycopg2-2.7.tar.gz#sha256=ceadecf660ad4f7a31ea5baef30a7351add8626f9fd3daaafabb9a9e549f3f9a (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.6.2.tar.gz (376 kB)
#      |████████████████████████████████| 376 kB 5.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
# ...
#   Downloading psycopg2-2.3.0.tar.gz (588 kB)
#      |████████████████████████████████| 588 kB 4.8 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_67c8ed92930947a1b0833d000576a7b9/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_67c8ed92930947a1b0833d000576a7b9/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-pfj3nuon
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_67c8ed92930947a1b0833d000576a7b9/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_67c8ed92930947a1b0833d000576a7b9/setup.py", line 247
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/68/0a/459df8dcbcc118ca435e9567abceaab919706908d52139e503f6396c4935/psycopg2-2.3.0.tar.gz#sha256=c17a06b7468debba94fa151d3ad93cd885d9cbe9a751e54ceb87738d5f0478ea (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.2.2.tar.gz (530 kB)
#      |████████████████████████████████| 530 kB 2.3 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_4488436922e84e5bb535c22fc4486d1c/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_4488436922e84e5bb535c22fc4486d1c/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-och25b2h
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_4488436922e84e5bb535c22fc4486d1c/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_4488436922e84e5bb535c22fc4486d1c/setup.py", line 245
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/63/3e/a4a35761eb4595fff89e63347b4f8e79c2095782fa5bc016a6dfb18b21ac/psycopg2-2.2.2.tar.gz#sha256=21a33d5b2609103512748098a06249492cc294790e07638fadc68cf06eeac39d (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.2.1.tar.gz (529 kB)
#      |████████████████████████████████| 529 kB 3.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_5f2981215d61421ca8fc74e60253f634/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_5f2981215d61421ca8fc74e60253f634/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-94xqgaz3
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_5f2981215d61421ca8fc74e60253f634/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_5f2981215d61421ca8fc74e60253f634/setup.py", line 239
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/de/c4/fdfb801035bd7da9e1ce98169d48ca2d6dee5b4361e349afbba40b3d7a5d/psycopg2-2.2.1.tar.gz#sha256=b0eca4e8438025dc57cacbea4e8ca2f5dc0554d41b1cdcc177757a5fc413f3d1 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.2.0.tar.gz (528 kB)
#      |████████████████████████████████| 528 kB 4.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_4ed49d76d6ba45a4b3b05fde70060bcb/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_4ed49d76d6ba45a4b3b05fde70060bcb/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-q_mk_mqc
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_4ed49d76d6ba45a4b3b05fde70060bcb/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_4ed49d76d6ba45a4b3b05fde70060bcb/setup.py", line 238
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/32/0c/2f4da04ae2a66d71eff37f19fce67506ad28f887851cd1c1cca35ba08b36/psycopg2-2.2.0.tar.gz#sha256=e70a8eabc491318beef4cd9cd9245a4d8dc62ee31cb74e7988913a66bb33f858 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.14.tar.gz (491 kB)
#      |████████████████████████████████| 491 kB 7.4 MB/s eta 0:00:01     |██████████████████████████████▊ | 471 kB 7.4 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_d7db77cf986e40c393c16a695d0c0c21/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_d7db77cf986e40c393c16a695d0c0c21/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-n7tzkyix
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_d7db77cf986e40c393c16a695d0c0c21/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_d7db77cf986e40c393c16a695d0c0c21/setup.py", line 238
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e0/1c/f0843f50a69fba3db880e9b267d36f6709bbf31a36fc46b82f75e8975ede/psycopg2-2.0.14.tar.gz#sha256=902607cdbe1195a00694d2b477eed8429eda433caaa0eb6ff7f80883e1c17ac7 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.13.tar.gz (258 kB)
#      |████████████████████████████████| 258 kB 4.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_77fbeca6c2f54f08a93bf9c8c0c97256/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_77fbeca6c2f54f08a93bf9c8c0c97256/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-fi4u8a7b
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_77fbeca6c2f54f08a93bf9c8c0c97256/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_77fbeca6c2f54f08a93bf9c8c0c97256/setup.py", line 233
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/7a/968afcb86b1958ae963a3aaa42c561e3ed2c2d4a8b773622b03856a16248/psycopg2-2.0.13.tar.gz#sha256=a15e622e101b16aa8ad44813d8fb1eced91379396c054aacbfa3ad658352332b (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.12.tar.gz (256 kB)
#      |████████████████████████████████| 256 kB 6.5 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_ff8dfd4cce7b421b885e2f1c371579ca/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_ff8dfd4cce7b421b885e2f1c371579ca/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-228t9x_e
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_ff8dfd4cce7b421b885e2f1c371579ca/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_ff8dfd4cce7b421b885e2f1c371579ca/setup.py", line 225
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6a/8d/ee5c330823d527a5cd14c833063f825211d7b5de6e4897f72e250c107d85/psycopg2-2.0.12.tar.gz#sha256=542c187531e756867fb60034c393b6f2beca34eeeb3ce2e0089a2b6fb8be1292 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.11.tar.gz (255 kB)
#      |████████████████████████████████| 255 kB 2.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6f19142b7aa948479cd61b127af4968a/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6f19142b7aa948479cd61b127af4968a/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-859bnor7
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6f19142b7aa948479cd61b127af4968a/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_6f19142b7aa948479cd61b127af4968a/setup.py", line 225
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2d/d7/496da11d7c81971870ddd36800419c4f84e8f6208aac5eabedf9f7748729/psycopg2-2.0.11.tar.gz#sha256=e6b4e0e41df97441eff34e00065376414da6488e0d55848a45cd77551dbae434 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.10.tar.gz (255 kB)
#      |████████████████████████████████| 255 kB 3.8 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_a70eb7714aa44910b1a603b382ebd81c/setup.py'"'"'; __file__='"'"'/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_a70eb7714aa44910b1a603b382ebd81c/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-pip-egg-info-v_yl4s0g
#          cwd: /private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_a70eb7714aa44910b1a603b382ebd81c/
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/2r/t1y3wfjs7jv2n22jhqjk41580000gn/T/pip-install-fr77yf02/psycopg2_a70eb7714aa44910b1a603b382ebd81c/setup.py", line 50, in <module>
#         import ConfigParser
#     ModuleNotFoundError: No module named 'ConfigParser'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/19/79/35c7596bab4456f3610c12ec542a94d51c6781ced587d1d85127210b879b/psycopg2-2.0.10.tar.gz#sha256=e40cc04b43849085725076ae134bfef9e3b087f6dd7c964aeeb930e2f0bc14ab (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement psycopg2
# ERROR: No matching distribution found for psycopg2
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 667 kB/s eta 0:00:011
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %% [markdown]
# ## Соединение с базой данных
#
# Чтобы подключиться к базе данных, нужно создать механизм (движок) SQLAlchemy. Механизм SQLAlchemy создает общий интерфейс с базой данных для выполнения операторов SQL.
#
# SQLAlchemy предоставляет функцию для создания механизма с учетом *строки подключения* и, возможно, некоторых дополнительных именованных (keywords) аргументов. Строка подключения может содержать:
#
# - Тип базы данных (Postgres, MySQL, etc.);
# - Диалект, если он отличается от установленного по умолчанию для конкретного типа базы данных (Psycopg2, PyMySQL и т. д.);
# - Дополнительные данные аутентификации (имя пользователя и пароль);
# - Расположение базы данных (файл или имя хоста сервера базы данных);
# - Дополнительный порт сервера базы данных;
# - Необязательное имя базы данных.
#
# Строка подключения позволяют нам использовать конкретный файл или место хранения. В примере 1 определяется файл базы данных SQLite с именем <TT>listings.db</tt>:
# - хранящийся в текущем каталоге;
# - в памяти;
# - с указанием полного пути к файлу (Unix и Windows).
#
# В Windows строка подключения будет иметь вид engine4; \\\ требуются для экранирования символа "слэш".
#
# Функция <TT>create_engine</tt> возвращает экземпляр механизма SQLAlchemy.

# %%
# 0-1. Создание механизма SQLAlchemy со строкой подключения SQLite

import sqlalchemy
from sqlalchemy import create_engine

engine = create_engine('sqlite:///listings.db')
# engine2 = create_engine('sqlite:///:memory:')
# engine3 = create_engine('sqlite:////home/Airbnb/listings.db')
# engine4 = create_engine('sqlite:///c:\\Users\\Airbnb\\listings.db')

# %% [markdown]
# PostgreSQL. Пример 2 демонстрирует создание механизма для локальной базы данных PostgreSQL с именем mydb

# %%
# 0-2. Создание механизма SQLAlchemy со строкой подключения PosrgreSQL

from sqlalchemy import create_engine
engine=create_engine('postgresql+psycopg2://username:password@localhost:5432/mydb')

# %% [markdown]
# MySQL. Пример 3 демонстрирует создание механизма для удаленной БД MySQL

# %%
# 0-3. Создание механизма SQLAlchemy со строкой подключения для удаленной БД MySQL

from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://username:password''@mysql01.mikhail.internal/listings', pool_recycle=3600)

# %% [markdown]
# Теперь, когда создан экземпляр механизма соединения с базой данных, мы можем начать использовать SQLAlchemy Core чтобы связать наше приложение с сервисами базы данных.

# %% [markdown]
# # 1. Схема и типы данных
#
# В SQLAlchemy имеется четыре категории типов данных:
# - Универсальный
# - Стандартный SQL
# - Зависящий от поставщика
# - Определяется пользователем
#
# Универсальная категория типов данных предназначена для сопоставления типов данных в Python и SQL.

# %%
import pandas as pd
pd.DataFrame(['BigInteger,int,BIGINT'.split(','),
              'Boolean,bool,BOOLEAN or SMALLINT'.split(','),
              'Date,datetime.date,DATE (SQLite: STRING)'.split(','),
              'DateTime,datetime.datetime,DATETIME (SQLite: STRING)'.split(','),
              'Enum,str,ENUM or VARCHAR'.split(','),
              'Float,float or Decimal,FLOAT or REAL'.split(','),
              'Integer,int,INTEGER'.split(','),
              'Interval,datetime.timedelta,INTERVAL or DATE from epoch'.split(','),
              'LargeBinary,byte,BLOB or BYTEA'.split(','),
              'Numeric,decimal.Decimal,NUMERIC or DECIMAL'.split(','),
              'Unicode,unicode,UNICODE or VARCHAR'.split(','),
              'Text,str,CLOB or TEXT'.split(','),
              'Time,datetime.time,DATETIME'.split(',')],
              columns='SQLAlchemy,Pyhon,SQL'.split(','))
# Out:
#      SQLAlchemy               Pyhon                          SQL
# 0    BigInteger                 int                       BIGINT
# 1       Boolean                bool          BOOLEAN or SMALLINT
# 2          Date       datetime.date        DATE (SQLite: STRING)
# 3      DateTime   datetime.datetime    DATETIME (SQLite: STRING)
# 4          Enum                 str              ENUM or VARCHAR
# 5         Float    float or Decimal                FLOAT or REAL
# 6       Integer                 int                      INTEGER
# 7      Interval  datetime.timedelta  INTERVAL or DATE from epoch
# 8   LargeBinary                byte                BLOB or BYTEA
# 9       Numeric     decimal.Decimal           NUMERIC or DECIMAL
# 10      Unicode             unicode           UNICODE or VARCHAR
# 11         Text                 str                 CLOB or TEXT
# 12         Time       datetime.time                     DATETIME

# %% [markdown]
# Стандартные типы (например CHAR и NVARCHAR)  используются в случаях, когда универсальные типы не отвечают требованиям из-за конкретной структуры данных.
#
# Типы, зависящие от поставщика. Пример: поле JSON в PostgreSQL.
#
# <TT>fromsqlalchemy.dialects.postgresqlimport JSON</tt>

# %% [markdown]
# ## Метаданные
#
# Метаданные используются для связывания структуры базы данных. Метаданные полезно рассматривать как каталог объектов таблиц с дополнительной информацией о механизме и соединении. Метаданные необходимо импортировать и инициализировать. Инициализируем экземпляр объектов MetaData:

# %%
# 1-1

from sqlalchemy import MetaData
metadata = MetaData()

# %% [markdown]
# ## Таблицы
#
# Объекты таблиц инициализируются в SQLAlchemy Core путем вызова конструктора <TT>Table</tt> с именем таблицы и метаданными, аргументы считаются объектами столбцов. Столбцы создаются путем вызова Column с именем, типом и затем аргументами, которые представляют дополнительные конструкции и ограничения SQL. В примере 4 создадим таблицу, которая может использоваться для перечня объектов размещения гостиничного бизнеса airbnb: http://insideairbnb.com/get-the-data.html

# %%
from sqlalchemy import (MetaData, Table, Column, Integer, Numeric, String, DateTime, Boolean, 
                        ForeignKey, create_engine)

# %%
# 1-2

listing=Table('listing',metadata,
               Column('listing_id',Integer(),primary_key=True),
               Column('listing_name',String(50),index=True),
               Column('listing_url',String(255)),
               Column('host_id',Integer()),
               Column('neighbourhood_id',Integer()),
               Column('amenities',String(255)),
               Column('property_type_id',Integer()),
               Column('room_type_id',Integer()),
               Column('bedrooms',Integer()),
               Column('beds',Integer()),
               Column('normal_price',Numeric(7,2)),
               extend_existing=True
              )

# %%
pd.DataFrame({'En':['listing_id','listing_name','listing_url','host_id','neighbourhood_id',
                  'amenities','property_type_id','room_type_id','bedrooms','beds','price'],
            'Ru':['идентификатор объекта размещения','имя объекта размещения',
                  'адрес веб-страницы','идентификатор владельца',
                  'идентификатор местоположения','оборудование, удобства',
                  'тип собственности','тип помещения','число кроватей','число спален','цена']})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5324edefe506> in <module>
# ----> 1 pd.DataFrame({'En':['listing_id','listing_name','listing_url','host_id','neighbourhood_id',
#       2                   'amenities','property_type_id','room_type_id','bedrooms','beds','price'],
#       3             'Ru':['идентификатор объекта размещения','имя объекта размещения',
#       4                   'адрес веб-страницы','идентификатор владельца',
#       5                   'идентификатор местоположения','оборудование, удобства',
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Дополнительные аргументы
#
# Рассмотрим использование дополнительных аргументов <TT>nullable, unique, onupdate</tt>

# %%
from datetime import datetime
from sqlalchemy import DateTime

# %%
# 1-3

user=Table('user',metadata,
            Column('user_id',Integer(),primary_key=True),
            Column('user_name',String(15),nullable=False,unique=True),
            Column('email_address',String(255),nullable=False),
            Column('phone',String(20),nullable=False),
            Column('password',String(25),nullable=False),
            Column('created_on',DateTime(),default=datetime.now),
            Column('updated_on',DateTime(),default=datetime.now,onupdate=datetime.now),
            extend_existing=True
           )

# %% [markdown]
# ### Ключи и ограничения
#
# Ключи и ограничения задают с помощью объектов <TT>PrimaryKeyConstraint, UniqueConstraint, CheckConstraint</tt>

# %%
from sqlalchemy import PrimaryKeyConstraint, UniqueConstraint, CheckConstraint

# %% [markdown]
# #### Первичный ключ
# В примерах 1-2 и 1-3  столбцы listing_id и user_id объявлялись первичными ключами с помощью ключевого слова primary_key. Также, можно определить составной первичный ключ, присвоив параметру primary_key значение True для нескольких столбцов. Таким образом, ключ рассматривается как кортеж, в котором столбцы, помеченные как ключ, присутствуют в порядке, в котором они были определены в таблице. Первичные ключи также могут быть определены после столбцов в конструкторе таблицы, как показано в следующем фрагменте.

# %%
user=Table('user',metadata,
            Column('user_name',String(15),nullable=False,unique=True),
            Column('email_address',String(255),nullable=False),
            Column('phone',String(20),nullable=False),
            Column('password',String(25),nullable=False),
            Column('created_on',DateTime(),default=datetime.now),
            Column('updated_on',DateTime(),default=datetime.now,onupdate=datetime.now),
            PrimaryKeyConstraint('user_id', name='user_pk'),
            extend_existing=True
           )

# %% [markdown]
# #### Уникальность
# Другое распространенное ограничение - ограничение уникальности, которое используется, чтобы гарантировать, что в данном поле значения не повторяются.
#
# <TT>UniqueConstraint('username', name='uix_username')</tt>

# %% [markdown]
# #### Проверка значения
# Этот тип ограничения используется, чтобы гарантировать, что данные, предоставленные для столбца, соответствуют набору критериев, определенных пользователем. В следующем фрагменте кода мы гарантируем, что <TT>price</tt> не может быть меньше 0,00:
#
# <TT>CheckConstraint('price >= 0.00', name='unit_cost_positive')</tt>

# %% [markdown]
# ### Индексы
#
# В примере 1-2 создан индекс для столбца listing_name. Когда индексы создаются, как показано в этом примере, они получают имена <TT>ix_listings_listing_name</tt>. Мы также можем определить индекс, используя явный тип конструкции. Можно обозначить несколько столбцов, разделив их запятой. Можно добавить аргумент ключевого слова <TT>unique = True</tt>, чтобы индекс был уникальным. При явном создании индексов они передаются в конструктор таблиц после столбцов. Чтобы имитировать указанный индекс явным способом, в конструктор <TT>Table</tt> требуется добавить <TT>Index('ix_listings_listing_name', 'listing_name')</tt>

# %%
from sqlalchemy import Index
Index('ix_listings_listing_name', 'listing_name')
# Out:
# Index('ix_listings_listing_name', 'listing_name')

# %% [markdown]
# Мы также можем создавать функциональные индексы для ситуаций, когда часто требуется запрос на основе нескольких полей БД. Например, если мы хотим искать по параметрам оборудования ("удобства") и цены в качестве объединенного элемента, можно определить функциональный индекс для оптимизации поиска:

# %%
Index('ix_test', listing.c.amenities, listing.c.price)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-aec401c38921> in <module>
# ----> 1 Index('ix_test', listing.c.amenities, listing.c.price)
#
# /usr/local/lib/python3.9/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: price

# %% [markdown]
# ### Связи и внешние ключи
# Тепрь, когда имеются пользователи и объекты размещения, необходимо обеспечить связи, позволяющие пользователям бронировать те или иные объекты. Рассмотрим схему данных.

# %% [markdown]
# <img src='./Image/listing_schema.png/'>

# %% [markdown]
# Создадим таблицы для заказов: <TT>order</tt> и <TT>line_item</tt>

# %%
from sqlalchemy import ForeignKey

# %%
# 1-4

order = Table('order', metadata,
               Column('order_id', Integer(),primary_key=True),
               Column('user_id', ForeignKey('user.user_id')),
               Column('confirmed', Boolean(),default=False),
               Column('order_price', Integer()),
               extend_existing=True
              )

# %%
# 1-5

line_item = Table('line_item', metadata,
                   Column('line_item_id', Integer(), primary_key=True),
                   Column('order_id', ForeignKey('order.order_id')),
                   Column('listing_id', ForeignKey('listing.listing_id')),
                   Column('item_start_date', DateTime()),
                   Column('item_end_date', DateTime()),
                   Column('item_price', Integer()),
                   extend_existing=True
                  )

# %% [markdown]
# В примерах 1-4 и 1-5 внешние ключи задаются с помощью строки: <TT>'order.order_id'</tt>. Также существует явный способ задания ограничений по внешнему ключу: <TT>ForeignKeyConstraint(['order_id'], ['order.order_id'])</tt>

# %% [markdown]
# ## Сохранение таблиц
#
# Все таблицы и определения связаны с экземпляром метаданных. Сохранение схемы в базе данных осуществляется посредством вызова метода <TT>create_all()</tt> в экземпляре метаданных с движком, в котором он должен создавать эти таблицы. По умолчанию create_all не будет пытаться воссоздать таблицы, которые уже существуют в базе данных, и его можно запускать несколько раз. Движок (механизм) SQLAlchemy определен нами ранее в примере 0-1, экземпляр метаданных создан ранее в примере 1-1. Теперь осуществим вызов метода <TT>create_all()</tt>

# %%
metadata.create_all(engine)

# %% [markdown]
# ## Дополнительно: DB Browser for SQLite
# https://sqlitebrowser.org/
